# %%
#!conda install -y -c anaconda seaborn=0.9.0
# Out:
# ...
# Solving environment: done
# ^C
#
# CondaError: KeyboardInterrupt

# %%
# LINE PLOT - Average Detection Delay

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

#Avg Detectoin delays for Sudden drift
df = pd.DataFrame({
   'Sudden Drift 2 SD': [27.6, 28.5, 28, 27.9, 26, 26.1],
   'Sudden Drift 1 SD': [15.9, 17.5, 18, 19.1, 21.3, 21],
   'Linear Drift 1 SD': [22, 23.6, 23.5, 24.9, 25.7, 27.1],
   'Linear Drift 2 SD': [31, 29.9, 30.4, 28.5, 28.8, 26.6]
   }, index=[0.2, 0.21, 0.22, 0.23, 0.24, 0.25])

plt.figure(figsize=(10,6), tight_layout=True)
#plotting
plt.plot(df, 'o--', linewidth=1)

#customization
plt.xticks([0.2, 0.21, 0.22, 0.23, 0.24, 0.25])
plt.xlabel('CUSUM Control Limit (Threshold)')
plt.ylabel('Average Detection Delay')
plt.title('CUSUM Average Detection Delay for Sudden and Linear Drift')
plt.legend(title='', title_fontsize = 13, labels=['Sudden Drift 2 SD', 'Sudden Drift 1 SD', 'Linear Drift 1 SD', 'Linear Drift 2 SD'])
plt.show()
plt.savefig('ADD.png')

# %%
# LINE PLOT 

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

#Avg Detectoin delays for Sudden drift
df = pd.DataFrame({
   'Sudden Drift 2 SD': [27.6, 28.5, 28, 27.9, 26, 26.1],
   'Sudden Drift 1 SD': [12.1, 12.88, 14.5, 14.5, 15.3, 16.4],
   'Linear Drift 1 SD': [22, 23.6, 23.5, 24.9, 25.7, 27.1],
   'Linear Drift 2 SD': [31, 29.9, 30.4, 28.5, 28.8, 26.6]
   }, index=[0.2, 0.21, 0.22, 0.23, 0.24, 0.25])
lines = df.plot.line(grid=False)
lines.set_facecolor('w')

# %%
# LINE PLOT - Linear Drift

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame({
   'drift= 1 SD': [22, 23.6, 23.5, 24.9, 25.7, 27.1],
   'drift = 0.5 SD': [31, 29.9, 30.4, 28.5, 28.8, 26.6]
   }, index=[0.2, 0.21, 0.22, 0.23, 0.24, 0.25])
lines = df.plot.line(grid=False)
lines.set_facecolor('w')

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.1
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
FP1S = [397, 292, 122, 175, 172, 97]  #Sudden Drift FP for k=0.03
FP1L = [425, 300, 122, 158, 113, 87]  #Linear Drift FP for k=0.03
#FP2S = [20, 11, 10, 0, 0, 3]  #Sudden Drift FP for k=0.05
#FP2L = [22, 11, 17, 7, 5, 0]  #Linear Drift FP for k=0.05
#FN = [0, 3, 9, 10, 11, 14]
 
# Set position of bar on X axis
br1 = np.arange(len(FP))
br2 = [x + barWidth for x in br1]
#br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, FP1S, color ='darkblue', width = barWidth,
        edgecolor ='none', label ='Sudden Drift 1 SD')
plt.bar(br2, FP1L, color ='powderblue', width = barWidth,
        edgecolor ='none', label ='Linear Drift 1 SD')
#plt.bar(br3, FP2S, color ='darkblue', width = barWidth,
        #edgecolor ='darkblue', label ='Sudden Drift 2 SD',  fill=False, hatch='//////')
#plt.bar(br3, FP2L, color ='powderblue', width = barWidth,
        #edgecolor ='powderblue', label ='Linear Drift 2 SD',  fill=False, hatch='//////')
#plt.grid(visible=None) 
#plt.rcParams['axes.facecolor'] = 'white'
#ax = plt.axes()
#ax.set_facecolor("white")
# Adding Xticks
plt.xlabel('CUSUM Control Limit (Threshold)', fontweight ='bold', fontsize = 10)
plt.ylabel('Number of False Positives', fontweight ='bold', fontsize = 10)
plt.xticks([r + barWidth for r in range(len(FP))],
        ['2.0', '2.1', '2.2', '2.3', '2.4', '2.5'])
plt.ylim(0, 500)
plt.legend()
plt.show()
plt.savefig('FP-SD1.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.1
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
TPS1 = [1000, 997, 991, 990, 989, 986]  #Sudden Drift TP for k=0.03
TPL1 = [996, 998, 992, 983, 988, 985]  #Linear Drift TP for k=0.03
TPS2 = [744, 704, 669, 624, 583, 545]  #Linear Drift TP for k=0.03
TPL2 = [751, 729, 689, 636, 609, 570]  #Linear Drift TP for k=0.03
#FN = [0, 3, 9, 10, 11, 14]
 
# Set position of bar on X axis
br1 = np.arange(len(FP))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
 
# Make the plot
plt.bar(br1, TPS1, color ='darkblue', width = barWidth,
        edgecolor ='none', label ='Sudden Drift 1 SD')
plt.bar(br2, TPL1, color ='powderblue', width = barWidth,
        edgecolor ='none', label ='Linear Drift 1 SD')
plt.bar(br3, TPS2, color ='darkblue', width = barWidth,
        edgecolor ='darkblue', label ='Sudden Drift 2 SD',  fill=False, hatch='//////')
plt.bar(br4, TPL2, color ='powderblue', width = barWidth,
        edgecolor ='powderblue', label ='Linear Drift 2 SD',  fill=False, hatch='//////')
    

#plt.grid(visible=None) 
#plt.rcParams['axes.facecolor'] = 'white'
#ax = plt.axes()
#ax.set_facecolor("white")
# Adding Xticks
plt.xlabel('CUSUM Control Limit (Threshold)', fontweight ='bold', fontsize = 10)
plt.ylabel('Number of True Positives', fontweight ='bold', fontsize = 10)
plt.xticks([r + barWidth for r in range(len(FP))],
        ['2.0', '2.1', '2.2', '2.3', '2.4', '2.5'])
 
plt.legend()
plt.show()
plt.savefig('TP-SD12.png')

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.1
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
FP1 = [20, 11, 10, 0, 0, 3]  #Sudden Drift FP for k=0.05
FP2 = [22, 11, 17, 7, 5, 0]  #Linear Drift FP for k=0.05
#FN = [0, 3, 9, 10, 11, 14]
 
# Set position of bar on X axis
br1 = np.arange(len(FP))
br2 = [x + barWidth for x in br1]
#br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, FP1, color ='darkblue', width = barWidth,
        edgecolor ='none', label ='Sudden Drift 2 SD')
plt.bar(br2, FP2, color ='powderblue', width = barWidth,
        edgecolor ='none', label ='Linear Drift 2 SD')
#plt.bar(br3, FN, color ='darkgrey', width = barWidth,
        #edgecolor ='darkgrey', label ='False Negatives',  fill=False, hatch='//////')
#plt.grid(visible=None) 
#plt.rcParams['axes.facecolor'] = 'white'
#ax = plt.axes()
#ax.set_facecolor("white")
# Adding Xticks
plt.xlabel('CUSUM Control Limit (Threshold)', fontweight ='bold', fontsize = 10)
plt.ylabel('Number of False Positives', fontweight ='bold', fontsize = 10)
plt.xticks([r + barWidth for r in range(len(FP))],
        ['2.0', '2.1', '2.2', '2.3', '2.4', '2.5'])
 
plt.legend()
plt.show()
plt.savefig('FP-SD2.png')

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant',
         'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,
                   'lifespan': lifespan}, index=index)
ax = df.plot.bar(rot=0)
speed1 = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan1 = [2, 8, 70, 1.5, 25, 12, 28]
df1 = pd.DataFrame({'speed': speed1,
                   'lifespan': lifespan1}, index=index)
ax = df.plot.bar(stacked=True)

# %%
import numpy as np

x = [324.925, 324.675, 324.725, 324.350, 325.350, 325.225, 324.125, 324.525, 325.225, 324.600, 324.625, 325.150, 328.325]
x = np.array(x)
np.mean(x)
# Out:
# 325.0634615384615

# %%
(0.76-0.86)/0.05
-1.99+0.049

# %%
# Import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# reading csv file - imported from RStudio - Plot AUC200
df = pd.read_csv("AUC_CUSUM200-hk.csv")
#print(df)
df.to_numpy()
#df.head(3)

chart = np.array([])
chart = df.to_numpy()

#chart[:,[0,1]]
np.round(chart, 2)
#print(df)

df = pd.DataFrame(chart)
#print(df.to_string())

cplus = chart[:,[6]]
cneg  = chart[:,[7]]
cusum = chart[:,[5]]

# PLOT 

plt.plot(cusum, '-b', label='CUSUM:x-mean')
plt.title('Cumulative Sum : x-mean')
plt.show()

# specifying horizontal line type
plt.axhline(y = -0.5, color = 'b', linestyle = '-')
plt.plot(cplus,  '-g', label='positive changes')
plt.plot(cneg, '-r', label='negative changes')
plt.title('Positive and Negative Changes')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 import matplotlib.pyplot as plt
#       6 # reading csv file - imported from RStudio - Plot AUC200
# ----> 7 df = pd.read_csv("AUC_CUSUM200-hk.csv")
#       8 #print(df)
#       9 df.to_numpy()
#
# File ~/.conda/envs/P3.8/lib/python3.8/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.conda/envs/P3.8/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
# Import pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# reading csv file - imported from RStudio - Plot AUC2000
df1 = pd.read_csv("AUC_CUSUM2000-new.csv")
print(df1)
df1.to_numpy()
#df.head(3)

chart1 = np.array([])
chart1 = df1.to_numpy()

#chart[:,[0,1]]
np.round(chart1, 2)

cplus2000 = chart1[:,[6]]
cneg2000  = chart1[:,[7]]
cusum2000 = chart1[:,[5]]

# PLOT 

plt.plot(cusum2000, '-b', label='CUSUM:x-mean')
plt.title('Cumulative Sum : x-mean')
plt.show()

plt.plot(cplus2000,  '-g', label='positive changes')
plt.plot(cneg2000, '-r', label='negative changes')
plt.title('Positive and Negative Changes')
plt.legend()
plt.show()

# %%
# Python3 program to find the
# first digit of X in base Y
import math
 
# Function to find the first
# digit of X in base Y
def first_digit(x, y):
     
    # Calculating number of digits of
    # x in base y
    length = int (math.log(x) /
                  math.log(y) + 1)
     
    # Finding first digit of x in base y
    first_digit = x / math.pow(y, length - 1)
 
    #print(int(first_digit))
    return (int(first_digit))
     
# Driver code
X = 25
Y = 10
 
d=first_digit(X, Y)
d
# Out:
# 2

# %%
# NIST CUSUM example from https://www.itl.nist.gov/div898/handbook/pmc/section3/pmc323.htm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
    
# 1D array 
x = [324.925, 324.675, 324.725, 324.350, 325.350, 325.225, 324.125, 324.525, 325.225, 324.600, 324.625, 325.150, 328.325, 327.250, 327.825, 328.500, 326.675, 327.775, 326.875, 328.350]
x = np.array(x)
num_rows = np.array(list(range(0,20)))

#arr.shape

#print("x : ", x) 
#print("mean of x : ", np.mean(x))
#print("std of x : ", np.std(x))

mu  = 325 # mu_hat0 - in-control mean
std = np.std(x)
h   = 4.1959
k   = 0.3175


#x_mean : Calculate x minus mu ------------------------------
x_mean = np.zeros(num_rows.size,dtype=float)
for i in range(0, num_rows.size):
    x_mean[i]  = x[i] - mu

x_mean = np.round(x_mean,decimals=2)

#Increase in mean = x-mu-k ----------------------------
mean_hi = np.zeros(num_rows.size,dtype=float)
for i in range(0, num_rows.size):
    mean_hi[i]  = x[i] - mu - k

#mean_hi = np.round(mean_hi,decimals=2)

#S_hi : for positive changes --------------------------
S_hi = np.zeros(num_rows.size,dtype=float)
S_hi[0] = 0.0 # starts with 0
for i in range(1, num_rows.size):
    S_hi[i]  = max(0, S_hi[i-1] + mean_hi[i])
    
S_hi = np.round(S_hi,decimals=2)

#Increase in mean = x-mu-k ----------------------------
mean_lo = np.zeros(num_rows.size,dtype=float)
for i in range(0, num_rows.size):
    mean_lo[i]  = mu - k - x[i]

mean_lo = np.round(mean_lo,decimals=2)

#S_lo : for negative changes --------------------------
S_lo = np.zeros(num_rows.size,dtype=float)
S_lo[0] = 0.0 # starts with 0
for i in range(1, num_rows.size):
    S_lo[i]  = max(0, S_lo[i-1] + mean_lo[i])
    
S_lo = np.round(S_lo,decimals=2)

#CUSUM: Cumulative sum of x minus mu ------------------
cusum = np.zeros(num_rows.size,dtype=float)
cusum[0] = 0.0 # initialize with 0
for i in range(0, num_rows.size):
    cusum[i] = cusum[i-1] + x_mean[i]
    #print(cusum[i],x_mean[i])
cusum = np.round(cusum,decimals=2)

# Construct the tabular CUSUM Chart
chart = np.array([])
chart = np.column_stack((x.T, x_mean.T, mean_hi.T, S_hi.T, mean_lo.T, S_lo.T, cusum.T))
np.round(chart, 2)

#d = 2 *(np.log((1-0.01) / (0.0027)))
#h = d * 0.5 # h= d*k where k=0.5
#h = 4 # as per the NIST doc on CUSUM

#l1 =  np.append(num_rows, data_tabular, axis = 1)
#l1 = np.concatenate(num_rows.T, data_tabular.T)
#chart = np.column_stack((num_rows.T, data_tabular.T))
#chart

np.set_printoptions(suppress=True,
   formatter={'float_kind':'{:0.2f}'.format})
#print("CUSUM Chart is:\n", np.round(chart,decimals=2))
#x_mean

df = pd.DataFrame(chart) 
df.columns = ['X','x-mu','Increase in Mean', 'S_hi', 'Decrease-in-mean', 'S_lo', 'CUSUM']
#print(cusum)
print(df)

plt.plot(cusum, "-o")
plt.title('Cumulative Sum')
plt.show()

plt.plot(S_hi,  '-gD', label='positive changes')
plt.plot(S_lo, '-rD', label='negative changes')
plt.title('Positive and Negative Changes')
plt.legend()
plt.show()
# Out:
#           X  x-mu  Increase in Mean   S_hi  Decrease-in-mean  S_lo  CUSUM
# 0   324.925 -0.07           -0.3925   0.00             -0.24  0.00  -0.07
# 1   324.675 -0.32           -0.6425   0.00              0.01  0.01  -0.39
# 2   324.725 -0.27           -0.5925   0.00             -0.04  0.00  -0.66
# 3   324.350 -0.65           -0.9675   0.00              0.33  0.33  -1.31
# 4   325.350  0.35            0.0325   0.03             -0.67  0.00  -0.96
# 5   325.225  0.23           -0.0925   0.00             -0.54  0.00  -0.73
# 6   324.125 -0.88           -1.1925   0.00              0.56  0.56  -1.61
# 7   324.525 -0.48           -0.7925   0.00              0.16  0.72  -2.09
# 8   325.225  0.23           -0.0925   0.00             -0.54  0.18  -1.86
# 9   324.600 -0.40           -0.7175   0.00              0.08  0.26  -2.26
# 10  324.625 -0.38           -0.6925   0.00              0.06  0.32  -2.64
# 11  325.150  0.15           -0.1675   0.00             -0.47  0.00  -2.49
# ...

# %%
# NIST CUSUM example from https://www.itl.nist.gov/div898/handbook/pmc/section3/pmc323.htm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
    
# 1D array 
x = [324.925, 324.675, 324.725, 324.350, 325.350, 325.225, 324.125, 324.525, 325.225, 324.600, 324.625, 325.150, 328.325, 327.250, 327.825, 328.500, 326.675, 327.775, 326.875, 328.350]
x = np.array(x)
num_rows = np.array(list(range(0,20)))

#arr.shape

#print("x : ", x) 
#print("mean of x : ", np.mean(x))
#print("std of x : ", np.std(x))

mu  = 325 # mu_hat0 - in-control mean
std = np.std(x)
h   = 4.1959
k   = 0.3175



x_mean = np.zeros(num_rows.size,dtype=float)
#S_hi : for positive changes --------------------------
S_hi = np.zeros(num_rows.size,dtype=float)
S_hi[0] = 0.0 # starts with 0
#Increase in mean = x-mu-k ----------------------------
mean_hi = np.zeros(num_rows.size,dtype=float)

#Decrease in mean = mu-k-x----------------------------
mean_lo = np.zeros(num_rows.size,dtype=float)
#S_lo : for negative changes --------------------------
S_lo = np.zeros(num_rows.size,dtype=float)
S_lo[0] = 0.0 # starts with 0


#CUSUM: Cumulative sum of x minus mu ------------------
cusum = np.zeros(num_rows.size,dtype=float)
cusum[0] = 0.0 # initialize with 0


for i in range(0, num_rows.size):
    x_mean[i]  = x[i] - mu  #x_mean 
    mean_hi[i] = x[i] - mu - k
    S_hi[i]    = max(0, S_hi[i-1] + mean_hi[i])
    mean_lo[i] = mu - k - x[i]
    S_lo[i]    = max(0, S_lo[i-1] + mean_lo[i])
    cusum[i]   = cusum[i-1] + x_mean[i]

x_mean  = np.round(x_mean,decimals=2)
S_hi    = np.round(S_hi,decimals=2)
mean_lo = np.round(mean_lo,decimals=2)
S_lo    = np.round(S_lo,decimals=2)
cusum   = np.round(cusum,decimals=2)

# Construct the tabular CUSUM Chart
chart = np.array([])
chart = np.column_stack((x.T, x_mean.T, mean_hi.T, S_hi.T, mean_lo.T, S_lo.T, cusum.T))
np.round(chart, 2)

#d = 2 *(np.log((1-0.01) / (0.0027)))
#h = d * 0.5 # h= d*k where k=0.5
#h = 4 # as per the NIST doc on CUSUM

#l1 =  np.append(num_rows, data_tabular, axis = 1)
#l1 = np.concatenate(num_rows.T, data_tabular.T)
#chart = np.column_stack((num_rows.T, data_tabular.T))
#chart

np.set_printoptions(suppress=True,
   formatter={'float_kind':'{:0.2f}'.format})
#print("CUSUM Chart is:\n", np.round(chart,decimals=2))
#x_mean

df = pd.DataFrame(chart) 
df.columns = ['X','x-mu','Increase in Mean', 'S_hi', 'Decrease-in-mean', 'S_lo', 'CUSUM']
#print(cusum)
print(df)

plt.plot(cusum, "-o")
plt.title('Cumulative Sum')
plt.show()

plt.plot(S_hi,  '-gD', label='positive changes')
plt.plot(S_lo, '-rD', label='negative changes')
plt.title('Positive and Negative Changes')
plt.legend()
plt.show()
# Out:
#           X  x-mu  Increase in Mean   S_hi  Decrease-in-mean  S_lo  CUSUM
# 0   324.925 -0.07           -0.3925   0.00             -0.24  0.00  -0.07
# 1   324.675 -0.32           -0.6425   0.00              0.01  0.01  -0.40
# 2   324.725 -0.27           -0.5925   0.00             -0.04  0.00  -0.67
# 3   324.350 -0.65           -0.9675   0.00              0.33  0.33  -1.32
# 4   325.350  0.35            0.0325   0.03             -0.67  0.00  -0.97
# 5   325.225  0.23           -0.0925   0.00             -0.54  0.00  -0.75
# 6   324.125 -0.88           -1.1925   0.00              0.56  0.56  -1.62
# 7   324.525 -0.48           -0.7925   0.00              0.16  0.72  -2.10
# 8   325.225  0.23           -0.0925   0.00             -0.54  0.17  -1.87
# 9   324.600 -0.40           -0.7175   0.00              0.08  0.25  -2.27
# 10  324.625 -0.38           -0.6925   0.00              0.06  0.31  -2.65
# 11  325.150  0.15           -0.1675   0.00             -0.47  0.00  -2.50
# ...

# %%
import pandas as pd
df = pd.read_csv (("CUSUM-out/file13.csv"),index_col=0, sep='\t')
print(df)

# Defining the columns to read
usecols1 = ["S_hi"]
usecols2 = ["S_lo"]
S_hi = pd.read_csv (("CUSUM-out/file13.csv"),index_col=0, usecols=usecols1, sep='\t')
S_lo = pd.read_csv (("CUSUM-out/file13.csv"),index_col=0, usecols=usecols2, sep='\t')
print(S_hi.to_numpy())
print(S_lo)

# Imports
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm # Colormaps
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable

# specifying horizontal line type
plt.axhline(y = 0.2, color = 'b', linestyle = '--')
plt.plot(S_hi,  '-g', label='positive changes')
plt.plot(S_lo, '-r', label='negative changes')
plt.title('Positive and Negative Changes')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#             X  x-mu  Increase in Mean  S_hi  Decrease-in-mean  S_lo  CUSUM
# 0    0.842949 -0.02         -0.045147  0.00             -0.01  0.00  -0.02
# 1    0.940705  0.08          0.052610  0.05             -0.11  0.00   0.07
# 2    0.901042  0.04          0.012946  0.07             -0.07  0.00   0.11
# 3    0.925134  0.07          0.037038  0.10             -0.10  0.00   0.18
# 4    0.824278 -0.03         -0.063817  0.04              0.00  0.00   0.14
# ..        ...   ...               ...   ...               ...   ...    ...
# 195  0.764368 -0.09         -0.123728  0.00              0.06  3.82  -6.65
# 196  0.842532 -0.02         -0.045563  0.00             -0.01  3.80  -6.67
# 197  0.866667  0.01         -0.021429  0.00             -0.04  3.77  -6.66
# ...

# %%
hi=df['S_hi'].values
lo=df['S_lo'].values
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
